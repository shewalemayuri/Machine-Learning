# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("D:\Data Science\car data.csv")
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()

# %%
new=encoder.fit_transform(df['Fuel_Type'])

# %%
df['Fuel_Type']=new
df.head(2)
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000          2
# 1      sx4  2013           4.75           9.54       43000          1
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0

# %%
df=pd.get_dummies(data=df,columns=['Seller_Type','Transmission'],drop_first=True)
df.head(2)
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  Fuel_Type  Owner  \
# 0     ritz  2014           3.35           5.59       27000          2      0
# 1      sx4  2013           4.75           9.54       43000          1      0
#
#    Seller_Type_Individual  Transmission_Manual
# 0                       0                    1
# 1                       0                    1

# %%
df['present_year']=2022
df['car_age']=df['present_year']-df['Year']
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  Fuel_Type  Owner  \
# 0     ritz  2014           3.35           5.59       27000          2      0
# 1      sx4  2013           4.75           9.54       43000          1      0
# 2     ciaz  2017           7.25           9.85        6900          2      0
# 3  wagon r  2011           2.85           4.15        5200          2      0
# 4    swift  2014           4.60           6.87       42450          1      0
#
#    Seller_Type_Individual  Transmission_Manual  present_year  car_age
# 0                       0                    1          2022        8
# 1                       0                    1          2022        9
# 2                       0                    1          2022        5
# 3                       0                    1          2022       11
# 4                       0                    1          2022        8

# %%
df.drop(labels=['Year','present_year','Car_Name'],axis=1,inplace=True)
df.head(2)
# Out:
#    Selling_Price  Present_Price  Kms_Driven  Fuel_Type  Owner  \
# 0           3.35           5.59       27000          2      0
# 1           4.75           9.54       43000          1      0
#
#    Seller_Type_Individual  Transmission_Manual  car_age
# 0                       0                    1        8
# 1                       0                    1        9

# %%
df.describe()
# Out:
#        Selling_Price  Present_Price     Kms_Driven   Fuel_Type       Owner  \
# count     301.000000     301.000000     301.000000  301.000000  301.000000
# mean        4.661296       7.628472   36947.205980    1.787375    0.043189
# std         5.082812       8.644115   38886.883882    0.425801    0.247915
# min         0.100000       0.320000     500.000000    0.000000    0.000000
# 25%         0.900000       1.200000   15000.000000    2.000000    0.000000
# 50%         3.600000       6.400000   32000.000000    2.000000    0.000000
# 75%         6.000000       9.900000   48767.000000    2.000000    0.000000
# max        35.000000      92.600000  500000.000000    2.000000    3.000000
#
#        Seller_Type_Individual  Transmission_Manual     car_age
# count              301.000000           301.000000  301.000000
# mean                 0.352159             0.867110    8.372093
# std                  0.478439             0.340021    2.891554
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()

# %%
X=df[['Kms_Driven']]

# %%
scaledX=scaler.fit_transform(X)
scaledX
# Out:
# array([[0.05305305],
#        [0.08508509],
#        [0.01281281],
#        [0.00940941],
#        [0.08398398],
#        [0.00314515],
#        [0.03662863],
#        [0.06592392],
#        [0.03958559],
#        [0.08381782],
#        [0.00327327],
#        [0.1011011 ],
#        [0.02902903],
#        [0.05105105],
#        [0.15400801],
#        [0.08508509],
#        [0.08243844],
#        [0.08508509],
#        [0.07007007],
#        [0.08196597],
#        [0.04904905],
#        [0.0038038 ],
#        [0.0990991 ],
#        [0.08964965],
#        [0.11287087],
#        [0.03903904],
#        [0.10938539],
#        [0.03143143],
#        [0.08817217],
#        [0.08908909],
#        [0.10197998],
#        [0.10750751],
#        [0.07707708],
#        [0.08908909],
#        [0.08908909],
#        [0.0990951 ],
#        [0.09663063],
#        [0.25325325],
#        [0.01917718],
#        [0.12312312],
#        [0.0480961 ],
#        [0.0925045 ],
#        [0.11511512],
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
X=df.drop('Selling_Price',axis=1)

# %%
X.head()
# Out:
#    Present_Price  Kms_Driven  Fuel_Type  Owner  Seller_Type_Individual  \
# 0           5.59       27000          2      0                       0
# 1           9.54       43000          1      0                       0
# 2           9.85        6900          2      0                       0
# 3           4.15        5200          2      0                       0
# 4           6.87       42450          1      0                       0
#
#    Transmission_Manual  car_age
# 0                    1        8
# 1                    1        9
# 2                    1        5
# 3                    1       11
# 4                    1        8

# %%
y=df.Selling_Price
y.head()
# Out:
# 0    3.35
# 1    4.75
# 2    7.25
# 3    2.85
# 4    4.60
# Name: Selling_Price, dtype: float64

# %%
model=LinearRegression()

# %%
model.fit(X,y)
# Out:
# LinearRegression()

# %%
model.score(X,y)
# Out:
# 0.8785205982910809

# %%
y_pred=model.predict(X)

# %%
from sklearn.model_selection import train_test_split

# %%
 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
X_train.shape
# Out:
# (240, 7)

# %%
X_test.shape
# Out:
# (61, 7)

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
model.score(X_test,y_test)
# Out:
# 0.846805395765744

# %%
model.predict(X_test)
# Out:
# array([ 2.96670467,  8.3025584 ,  6.05620758, -1.46814968,  9.25713882,
#         7.032306  ,  1.35164871,  0.8268692 ,  1.37173108,  7.10742891,
#         8.74382695,  0.58613312,  8.50347194,  3.42803571,  6.50183791,
#         3.08701389,  0.46323861, 10.8959559 ,  1.76487652,  2.36736645,
#         0.37538646,  7.73247978,  6.2075281 ,  2.64722707,  0.78232086,
#         3.72073841,  5.33393873,  2.83824054,  2.16090172,  1.77220708,
#         0.37859447,  8.79078642, -0.7007019 ,  2.2988819 ,  8.21516023,
#         4.54037167,  7.35322104,  7.68237569,  2.91768184,  8.08080852,
#         3.99669454,  4.34672417,  4.36388106,  0.61018923,  6.94478948,
#         0.47281585,  7.41596672, 11.44059317,  3.14822313,  4.95097368,
#         6.86250813,  2.19862524, 20.53946595, 16.79146986,  7.13952545,
#         9.830903  ,  4.49886186,  8.62078376,  1.810855  ,  7.67299866,
#         0.21098592])

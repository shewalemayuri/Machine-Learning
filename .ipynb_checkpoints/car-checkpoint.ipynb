# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("D:\Data Science\car data.csv")
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder=LabelEncoder()

# %%
new=encoder.fit_transform(df['Fuel_Type'])

# %%
df['Fuel_Type']=new
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000          2
# 1      sx4  2013           4.75           9.54       43000          1
# 2     ciaz  2017           7.25           9.85        6900          2
# 3  wagon r  2011           2.85           4.15        5200          2
# 4    swift  2014           4.60           6.87       42450          1
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
df1=pd.get_dummies(data=df,columns=['Seller_Type','Transmission'],drop_first=True)
df1.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  Fuel_Type  Owner  \
# 0     ritz  2014           3.35           5.59       27000          2      0
# 1      sx4  2013           4.75           9.54       43000          1      0
# 2     ciaz  2017           7.25           9.85        6900          2      0
# 3  wagon r  2011           2.85           4.15        5200          2      0
# 4    swift  2014           4.60           6.87       42450          1      0
#
#    Seller_Type_Individual  Transmission_Manual
# 0                       0                    1
# 1                       0                    1
# 2                       0                    1
# 3                       0                    1
# 4                       0                    1

# %%
from datetime import date

# %%
Year=df['Year']

# %%
def car_age(Year):
    today=date.today()

# %%
car_age=today.year-Year
car_age
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [52], in <cell line: 1>()
# ----> 1 car_age=today.year-Year
#       2 car_age
#
# NameError: name 'today' is not defined

# %%
df1['Year']=car_age
df1
# Out:
#     Car_Name                                      Year  Selling_Price  \
# 0       ritz  <function car_age at 0x00000143B5C60EE0>           3.35
# 1        sx4  <function car_age at 0x00000143B5C60EE0>           4.75
# 2       ciaz  <function car_age at 0x00000143B5C60EE0>           7.25
# 3    wagon r  <function car_age at 0x00000143B5C60EE0>           2.85
# 4      swift  <function car_age at 0x00000143B5C60EE0>           4.60
# ..       ...                                       ...            ...
# 296     city  <function car_age at 0x00000143B5C60EE0>           9.50
# 297     brio  <function car_age at 0x00000143B5C60EE0>           4.00
# 298     city  <function car_age at 0x00000143B5C60EE0>           3.35
# 299     city  <function car_age at 0x00000143B5C60EE0>          11.50
# 300     brio  <function car_age at 0x00000143B5C60EE0>           5.30
#
#      Present_Price  Kms_Driven  Fuel_Type  Owner  Seller_Type_Individual  \
# 0             5.59       27000          2      0                       0
# 1             9.54       43000          1      0                       0
# 2             9.85        6900          2      0                       0
# 3             4.15        5200          2      0                       0
# 4             6.87       42450          1      0                       0
# ..             ...         ...        ...    ...                     ...
# 296          11.60       33988          1      0                       0
# 297           5.90       60000          2      0                       0
# 298          11.00       87934          2      0                       0
# 299          12.50        9000          1      0                       0
# 300           5.90        5464          2      0                       0
#
#      Transmission_Manual
# 0                      1
# 1                      1
# 2                      1
# 3                      1
# 4                      1
# ..                   ...
# 296                    1
# 297                    1
# 298                    1
# 299                    1
# 300                    1
#
# [301 rows x 9 columns]

# %%
table=df1.drop("Car_Name",axis=1)
table
# Out:
#                                          Year  Selling_Price  Present_Price  \
# 0    <function car_age at 0x00000143B5C60EE0>           3.35           5.59
# 1    <function car_age at 0x00000143B5C60EE0>           4.75           9.54
# 2    <function car_age at 0x00000143B5C60EE0>           7.25           9.85
# 3    <function car_age at 0x00000143B5C60EE0>           2.85           4.15
# 4    <function car_age at 0x00000143B5C60EE0>           4.60           6.87
# ..                                        ...            ...            ...
# 296  <function car_age at 0x00000143B5C60EE0>           9.50          11.60
# 297  <function car_age at 0x00000143B5C60EE0>           4.00           5.90
# 298  <function car_age at 0x00000143B5C60EE0>           3.35          11.00
# 299  <function car_age at 0x00000143B5C60EE0>          11.50          12.50
# 300  <function car_age at 0x00000143B5C60EE0>           5.30           5.90
#
#      Kms_Driven  Fuel_Type  Owner  Seller_Type_Individual  Transmission_Manual
# 0         27000          2      0                       0                    1
# 1         43000          1      0                       0                    1
# 2          6900          2      0                       0                    1
# 3          5200          2      0                       0                    1
# 4         42450          1      0                       0                    1
# ..          ...        ...    ...                     ...                  ...
# 296       33988          1      0                       0                    1
# 297       60000          2      0                       0                    1
# 298       87934          2      0                       0                    1
# 299        9000          1      0                       0                    1
# 300        5464          2      0                       0                    1
#
# [301 rows x 8 columns]

# %%
X=table.drop("Selling_Price",axis=1)
X.head(2)
# Out:
#                                        Year  Present_Price  Kms_Driven  \
# 0  <function car_age at 0x00000143B5C60EE0>           5.59       27000
# 1  <function car_age at 0x00000143B5C60EE0>           9.54       43000
#
#    Fuel_Type  Owner  Seller_Type_Individual  Transmission_Manual
# 0          2      0                       0                    1
# 1          1      0                       0                    1

# %%
y=df1.Selling_Price
y
# Out:
# 0       3.35
# 1       4.75
# 2       7.25
# 3       2.85
# 4       4.60
#        ...
# 296     9.50
# 297     4.00
# 298     3.35
# 299    11.50
# 300     5.30
# Name: Selling_Price, Length: 301, dtype: float64

# %%
new=scale.fit_transform(X)

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model.fit(new,y)

# %%
model.score(new,y)

# %%
model.predict(new)

# %%
from sklearn.model_selection import train_test_split

# %%
 X_train, X_test, y_train, y_test = train_test_split(new, y, test_size=0.20, random_state=42)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [13], in <cell line: 1>()
# ----> 1 X_train, X_test, y_train, y_test = train_test_split(new, y, test_size=0.20, random_state=42)
#
# NameError: name 'y' is not defined

# %%
X_train.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [14], in <cell line: 1>()
# ----> 1 X_train.shape
#
# NameError: name 'X_train' is not defined

# %%
X_test.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [15], in <cell line: 1>()
# ----> 1 X_test.shape
#
# NameError: name 'X_test' is not defined

# %%
scale.fit(X_train,y_train)
# Out:
# MinMaxScaler()

# %%
model.score(X_train,y_train)
# Out:
# 0.8827807788950326

# %%
model.predict(X_test)
